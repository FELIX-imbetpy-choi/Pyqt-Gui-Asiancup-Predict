# %%
from selenium import webdriver
import urllib.request as req
from bs4 import BeautifulSoup
import pandas as pd

# %%
korea_china_2015 = pd.read_csv('./korea_china_players_2015.csv')
uzbek_2015 = pd.read_csv('./Data/uzbek_player_2015.csv')
australia_2015 = pd.read_csv('./Data/australia_player_2015.csv')
oman_irak_2015 = pd.read_csv('./Data/oman_irak_player_2015.csv')
pala_katar_2015 = pd.read_csv('./Data/pala_katar_player_2015.csv')
kuwait_2015 = pd.read_csv('./Data/kuwait_player_2015.csv')
saudi_2015 = pd.read_csv('./Data/saudi_player_2015.csv')
north_korea_2015 = pd.read_csv('./Data/north-korea_player_2015.csv')
iran_2015 = pd.read_csv('./Data/iran_player_2015.csv')
uae_2015 = pd.read_csv('./Data/uae_player_2015.csv')
bahrain_2015 = pd.read_csv('./Data/bahrain_player_2015.csv')
japan_2015 = pd.read_csv('./Data/japan_player_2015.csv')
jordan_2015 = pd.read_csv('./Data/jordan_player_2015.csv')

# %%
players_2015 = pd.concat([korea_china_2015,uzbek_2015,australia_2015,oman_irak_2015,pala_katar_2015,kuwait_2015,
                         saudi_2015,north_korea_2015,iran_2015,uae_2015,bahrain_2015,japan_2015,jordan_2015])

# %%
del players_2015['age']
del players_2015['cap']
del players_2015['goal']
del players_2015['nation']

# %%
players_2015_main = pd.read_csv('./Data/semi_players_2015.csv')

# %%
len(players_2015)
# Out:
# 367

# %%
len(players_2015_main)
# Out:
# 367

# %%
players_2015_total = pd.merge(players_2015_main, players_2015, on = 'name')

# %%
players_2015_total.to_csv('./Data/total_players_2015.csv',index=False,header=True)

# %%
players_2015_total
# Out:
#      age  cap  goal                 name                      club  \
# 0     22   13     0          Mathew Ryan               Club Brugge
# 1     27   12     0         Ivan Franjic            Torpedo Moscow
# 2     23   13     0       Jason Davidson      West Bromwich Albion
# 3     35   77    36           Tim Cahill        New York Red Bulls
# 4     29   33     2        Mark Milligan         Melbourne Victory
# 5     26   21     0   Matthew Spiranovic  Western Sydney Wanderers
# 6     23   16     1        Mathew Leckie             Ingolstadt 04
# 7     25    3     0           Chris Herd               Aston Villa
# 8     23    5     1           Tomi Juric  Western Sydney Wanderers
# 9     26   32     3         Robbie Kruse          Bayer Leverkusen
# 10    23   21     1            Tommy Oar                FC Utrecht
# 11    26    5     0    Mitchell Langerak         Borussia Dortmund
# 12    24    7     2          Aziz Behich                 Bursaspor
# ...

# %%
# database로 넣기
import pymysql
from sqlalchemy import create_engine

# %%
# Table의 column이름과 df의 column 이름이 일치해야함.
column = colnames = ['age','cap','goal','name','club','nation','height','salary']
total_players = pd.read_csv('./Data/total_players_2015.csv')
total_players = pd.DataFrame(total_players)
total_players.columns = column
total_players.head()
# Out:
#    age  cap  goal            name                  club     nation  height  \
# 0   22   13     0     Mathew Ryan           Club Brugge  Australia     184
# 1   27   12     0    Ivan Franjic        Torpedo Moscow  Australia     180
# 2   23   13     0  Jason Davidson  West Bromwich Albion  Australia     180
# 3   35   77    36      Tim Cahill    New York Red Bulls  Australia     180
# 4   29   33     2   Mark Milligan     Melbourne Victory  Australia     178
#
#    salary
# 0  270000
# 1     540
# 2     360
# 3     900
# 4     675

# %%
engine = create_engine("mysql+pymysql://root:" + "1111" + 
                       "@192.168.35.143:3306/asiancup?charset=utf8",
                      encoding = 'utf-8')
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     581                                 (self.host, self.port), self.connect_timeout,
# --> 582                                 **kwargs)
#     583                             break
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# OSError: [Errno 64] Host is down
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
total_players.to_sql(name = 'players_2015', con = engine, if_exists = 'append', index = False)
