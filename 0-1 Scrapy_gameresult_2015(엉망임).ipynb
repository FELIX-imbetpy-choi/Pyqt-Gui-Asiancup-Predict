# %%
from selenium import webdriver
import urllib.request as req
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('http://www.football-lineups.com/match/191202/')

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
print(team1)
print(team2)
# Out:
# Oman
# Australia

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
print(time[0:2])
print(time[1])
# Out:
# ['13-Jan-15', '20:00']
# 20:00

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
print(weather[0].text)
print(weather[1].text)
# Out:
#  3:58 pm AEDT  Partly Cloudy 26C
#  8:29 pm AEDT  Light Rain Shower 24C

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[187:]
print(detail[3].text)
print(detail[5].text)
print(detail[6].text)
print(detail[8].text)
print(detail[15].text)
print(detail[17].text)
# print(detail[15].text)
# print(detail[16].text)
# print(detail[17].text)
# Out:
# 3
# 4
# 19
# 26
# 47
# 53

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

# for i in range(75004):
#     url_base = 'http://www.football-lineups.com/match/'
#     url_sub = str(i)
#     driver.get(url_base + url_sub)
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
team1List.append(team1)
team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
team2List.append(team2)
time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
timeList.append(time[0:2])
weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
weather1List.append(weather[0].text)
weather2List.append(weather[1].text)
detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[187:]
Shots1List.append(detail[3].text)
Shots2List.append(detail[5].text)
Fouls1List.append(detail[6].text)
Fouls2List.append(detail[8].text)
possession1List.append(detail[15].text)
possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['South Korea']
# ['Australia']
# [['31-Jan-15', '20:00']]
# [' 5:28 pm AEDT  Fair 24C']
# [' 8:59 pm AEDT  Fair 22C']
# ['3']
# ['4']
# ['19']
# ['26']
# ['47']
# ['53']

# %%
gamedetail_aus_2011 = pd.DataFrame(team1List)
gamedetail_aus_2011 = gamedetail_aus_2011.rename(columns = {0:'team1'})
gamedetail_aus_2011['team2'] = team2List
gamedetail_aus_2011['gameday'] = timeList
gamedetail_aus_2011['weather_d'] = weather1List
gamedetail_aus_2011['weather_t'] = weather2List
gamedetail_aus_2011['shoot1'] = Shots1List
gamedetail_aus_2011['shoot2'] = Shots2List
gamedetail_aus_2011['foul1'] = Fouls1List
gamedetail_aus_2011['foul2'] = Fouls2List
gamedetail_aus_2011['possession1'] = possession1List
gamedetail_aus_2011['possession2'] = possession2List

# %%
gamedetail_aus_2011
# Out:
#          team1      team2             gameday                weather_d  \
# 0  South Korea  Australia  [31-Jan-15, 20:00]   5:28 pm AEDT  Fair 24C
#
#                  weather_t shoot1 shoot2 foul1 foul2 possession1 possession2
# 0   8:59 pm AEDT  Fair 22C      3      4    19    26          47          53

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_aus_2011])

# %%
gamedetail_2015.sort_values(by='gameday')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-360-2fc4d60a51b6> in <module>
# ----> 1 gamedetail_2015.sort_values(by='gameday')
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4723
#    4724             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 4725                                na_position=na_position)
#    4726
#    4727         new_data = self._data.take(indexer,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     264         non_nans = non_nans[::-1]
#     265         non_nan_idx = non_nan_idx[::-1]
# --> 266     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     267     if not ascending:
#     268         indexer = indexer[::-1]
#
# ...

# %%
gamedetail_2015.to_csv('./gamedetail_2015.csv',index=False,header=True)

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

for i in range(191206,191208):
    url_base = 'http://www.football-lineups.com/match/'
    url_sub = str(i)
    driver.get(url_base + url_sub)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
    team1List.append(team1)
    team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
    team2List.append(team2)
    time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
    timeList.append(time[0:2])
    weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
    weather1List.append(weather[0].text)
    weather2List.append(weather[1].text)
    detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[186:]
    Shots1List.append(detail[3].text)
    Shots2List.append(detail[5].text)
    Fouls1List.append(detail[6].text)
    Fouls2List.append(detail[8].text)
    possession1List.append(detail[15].text)
    possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['Australia', 'Oman']
# ['South Korea', 'Kuwait']
# [['17-Jan-15', '19:00'], ['17-Jan-15', '20:00']]
# [' 5:30 pm AEST  Partly Cloudy 29C', ' 6:00 pm AEDT  Unknown Precipitation 27C']
# [' 7:59 pm AEST  Partly Cloudy 27C', ' 8:29 pm AEDT  Unknown 26C']
# ['6', '3']
# ['3', '1']
# ['19', '16']
# ['13', '8']
# ['67', '41']
# ['33', '59']

# %%
gamedetail_two_2011 = pd.DataFrame(team1List)
gamedetail_two_2011 = gamedetail_two_2011.rename(columns = {0:'team1'})
gamedetail_two_2011['team2'] = team2List
gamedetail_two_2011['gameday'] = timeList
gamedetail_two_2011['weather_d'] = weather1List
gamedetail_two_2011['weather_t'] = weather2List
gamedetail_two_2011['shoot1'] = Shots1List
gamedetail_two_2011['shoot2'] = Shots2List
gamedetail_two_2011['foul1'] = Fouls1List
gamedetail_two_2011['foul2'] = Fouls2List
gamedetail_two_2011['possession1'] = possession1List
gamedetail_two_2011['possession2'] = possession2List

# %%
gamedetail_two_2011
# Out:
#        team1        team2             gameday  \
# 0  Australia  South Korea  [17-Jan-15, 19:00]
# 1       Oman       Kuwait  [17-Jan-15, 20:00]
#
#                                   weather_d                         weather_t  \
# 0           5:30 pm AEST  Partly Cloudy 29C   7:59 pm AEST  Partly Cloudy 27C
# 1   6:00 pm AEDT  Unknown Precipitation 27C         8:29 pm AEDT  Unknown 26C
#
#   shoot1 shoot2 foul1 foul2 possession1 possession2
# 0      6      3    19    13          67          33
# 1      3      1    16     8          41          59

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_two_2011])

# %%
gamedetail_2015
# Out:
#          team1        team2             gameday  \
# 0    Australia       Kuwait  [09-Jan-15, 20:00]
# 1  South Korea         Oman  [10-Jan-15, 16:00]
# 2       Kuwait  South Korea  [13-Jan-15, 18:00]
# 0         Oman    Australia  [13-Jan-15, 20:00]
# 0    Australia  South Korea  [17-Jan-15, 19:00]
# 1         Oman       Kuwait  [17-Jan-15, 20:00]
#
#                                     weather_d  \
# 0                6:00 pm AEDT  Light Rain 16C
# 1                      7:00 pm AEDT  Rain 19C
# 2   3:58 pm AEDT  Showers in the Vicinity 24C
# 0             3:58 pm AEDT  Partly Cloudy 26C
# 0             5:30 pm AEST  Partly Cloudy 29C
# 1     6:00 pm AEDT  Unknown Precipitation 27C
#
#                               weather_t shoot1     shoot2 foul1    foul2  \
# 0       8:29 pm AEDT  Light Drizzle 14C      8          5    19       10
# 1          9:29 pm AEDT  Light Rain 18C      3  Offsides      -  Time %
# 2   6:00 pm AEDT  Light Rain Shower 22C      3  Offsides      2  Time %
# ...

# %%
# gamedetail_2011_t.to_csv('./gamedetail_2011.csv',index=False,header=True)

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

# for i in range(75004):
#     url_base = 'http://www.football-lineups.com/match/'
#     url_sub = str(i)
#     driver.get(url_base + url_sub)
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
team1List.append(team1)
team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
team2List.append(team2)
time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
timeList.append(time[0:2])
weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
weather1List.append(weather[0].text)
weather2List.append(weather[1].text)
detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[178:]
Shots1List.append(detail[3].text)
Shots2List.append(detail[5].text)
Fouls1List.append(detail[6].text)
Fouls2List.append(detail[8].text)
possession1List.append(detail[15].text)
possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['Japan']
# ['Jordan']
# [['20-Jan-15', '20:00']]
# [' 3:58 pm AEDT  Mostly Cloudy 29C']
# [' 8:59 pm AEDT  Fair 25C']
# ['9']
# ['1']
# ['21']
# ['14']
# ['66']
# ['34']

# %%
gamedetail_two_2011 = pd.DataFrame(team1List)
gamedetail_two_2011 = gamedetail_two_2011.rename(columns = {0:'team1'})
gamedetail_two_2011['team2'] = team2List
gamedetail_two_2011['gameday'] = timeList
gamedetail_two_2011['weather_d'] = weather1List
gamedetail_two_2011['weather_t'] = weather2List
gamedetail_two_2011['shoot1'] = Shots1List
gamedetail_two_2011['shoot2'] = Shots2List
gamedetail_two_2011['foul1'] = Fouls1List
gamedetail_two_2011['foul2'] = Fouls2List
gamedetail_two_2011['possession1'] = possession1List
gamedetail_two_2011['possession2'] = possession2List

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_two_2011])

# %%
gamedetail_2015
# Out:
#                   team1                 team2             gameday  \
# 0             Australia                Kuwait  [09-Jan-15, 20:00]
# 1           South Korea                  Oman  [10-Jan-15, 16:00]
# 2                Kuwait           South Korea  [13-Jan-15, 18:00]
# 0                  Oman             Australia  [13-Jan-15, 20:00]
# 0             Australia           South Korea  [17-Jan-15, 19:00]
# 1                  Oman                Kuwait  [17-Jan-15, 20:00]
# 0            Uzbekistan           North Korea  [10-Jan-15, 18:00]
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 3            Uzbekistan          Saudi Arabia  [18-Jan-15, 20:00]
# 4             China, PR           North Korea  [18-Jan-15, 20:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# ...

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

for i in range(191209,191219):
    url_base = 'http://www.football-lineups.com/match/'
    url_sub = str(i)
    driver.get(url_base + url_sub)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
    team1List.append(team1)
    team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
    team2List.append(team2)
    time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
    timeList.append(time[0:2])
    weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
    weather1List.append(weather[0].text)
#     weather2List.append(weather[1].text)
    detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[186:]
    Shots1List.append(detail[3].text)
    Shots2List.append(detail[5].text)
    Fouls1List.append(detail[6].text)
    Fouls2List.append(detail[8].text)
    possession1List.append(detail[15].text)
    possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['Saudi Arabia', 'North Korea', 'China, PR', 'Uzbekistan', 'China, PR', 'United Arab Emirates', 'Iran', 'Bahrain', 'Qatar', 'Iran']
# ['China, PR', 'Saudi Arabia', 'Uzbekistan', 'Saudi Arabia', 'North Korea', 'Qatar', 'Bahrain', 'United Arab Emirates', 'Iran', 'United Arab Emirates']
# [['10-Jan-15', '19:00'], ['14-Jan-15', '18:00'], ['14-Jan-15', '19:00'], ['18-Jan-15', '20:00'], ['18-Jan-15', '20:00'], ['11-Jan-15', '18:00'], ['11-Jan-15', '20:00'], ['15-Jan-15', '18:00'], ['15-Jan-15', '20:00'], ['19-Jan-15', '19:00']]
# [' 3:58 pm AEST  Showers in the Vicinity 28C', ' 4:58 pm AEDT  Mostly Cloudy/Windy 20C', ' 3:58 pm AEST  Light Rain Shower 26C', ' 7:00 pm AEDT  Mostly Cloudy 16C', ' 6:30 pm AEDT  Unknown 25C', ' 4:58 pm AEDT  Mostly Cloudy 22C', ' 7:00 pm AEDT  Partly Cloudy 25C', ' 4:58 pm AEDT  Fair 26C', ' 4:28 pm AEDT  Partly Cloudy 25C', ' 5:30 pm AEST  Showers in the Vicinity 28C']
# []
# ['1', '12', '3', "93'", '2', '8', '4', '4', '1', 'Shots on gol ']
# ...

# %%
weather2List=['','','','','','','','','','']

# %%
gamedetail_qf_2011 = pd.DataFrame(team1List)
gamedetail_qf_2011 = gamedetail_qf_2011.rename(columns = {0:'team1'})
gamedetail_qf_2011['team2'] = team2List
gamedetail_qf_2011['gameday'] = timeList
gamedetail_qf_2011['weather_d'] = weather1List
gamedetail_qf_2011['weather_t'] = weather2List
gamedetail_qf_2011['shoot1'] = Shots1List
gamedetail_qf_2011['shoot2'] = Shots2List
gamedetail_qf_2011['foul1'] = Fouls1List
gamedetail_qf_2011['foul2'] = Fouls2List
gamedetail_qf_2011['possession1'] = possession1List
gamedetail_qf_2011['possession2'] = possession2List

# %%
gamedetail_qf_2011
# Out:
#                   team1                 team2             gameday  \
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 3            Uzbekistan          Saudi Arabia  [18-Jan-15, 20:00]
# 4             China, PR           North Korea  [18-Jan-15, 20:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# 6                  Iran               Bahrain  [11-Jan-15, 20:00]
# 7               Bahrain  United Arab Emirates  [15-Jan-15, 18:00]
# 8                 Qatar                  Iran  [15-Jan-15, 20:00]
# 9                  Iran  United Arab Emirates  [19-Jan-15, 19:00]
#
#                                     weather_d weather_t         shoot1  \
# 0   3:58 pm AEST  Showers in the Vicinity 28C                        1
# 1       4:58 pm AEDT  Mostly Cloudy/Windy 20C                       12
# ...

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_qf_2011])

# %%
gamedetail_2015
# Out:
#                   team1                 team2             gameday  \
# 0             Australia                Kuwait  [09-Jan-15, 20:00]
# 1           South Korea                  Oman  [10-Jan-15, 16:00]
# 2                Kuwait           South Korea  [13-Jan-15, 18:00]
# 0                  Oman             Australia  [13-Jan-15, 20:00]
# 0             Australia           South Korea  [17-Jan-15, 19:00]
# 1                  Oman                Kuwait  [17-Jan-15, 20:00]
# 0            Uzbekistan           North Korea  [10-Jan-15, 18:00]
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 3            Uzbekistan          Saudi Arabia  [18-Jan-15, 20:00]
# 4             China, PR           North Korea  [18-Jan-15, 20:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# ...

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

# for i in range(75004):
#     url_base = 'http://www.football-lineups.com/match/'
#     url_sub = str(i)
#     driver.get(url_base + url_sub)
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')
team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
team1List.append(team1)
team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
team2List.append(team2)
time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
timeList.append(time[0:2])
weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
weather1List.append(weather[0].text)
weather2List.append(weather[1].text)
detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[170:]
Shots1List.append(detail[3].text)
Shots2List.append(detail[5].text)
Fouls1List.append(detail[6].text)
Fouls2List.append(detail[8].text)
possession1List.append(detail[15].text)
possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['Iraq']
# ['Palestine']
# [['20-Jan-15', '20:00']]
# [' 3:58 pm AEDT  Mostly Cloudy 24C']
# [' 8:29 pm AEDT  Mostly Cloudy 19C']
# ['8']
# ['1']
# ['15']
# ['9']
# ['64']
# ['36']

# %%
gamedetail_qf_2011 = pd.DataFrame(team1List)
gamedetail_qf_2011 = gamedetail_qf_2011.rename(columns = {0:'team1'})
gamedetail_qf_2011['team2'] = team2List
gamedetail_qf_2011['gameday'] = timeList
gamedetail_qf_2011['weather_d'] = weather1List
gamedetail_qf_2011['weather_t'] = weather2List
gamedetail_qf_2011['shoot1'] = Shots1List
gamedetail_qf_2011['shoot2'] = Shots2List
gamedetail_qf_2011['foul1'] = Fouls1List
gamedetail_qf_2011['foul2'] = Fouls2List
gamedetail_qf_2011['possession1'] = possession1List
gamedetail_qf_2011['possession2'] = possession2List

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_qf_2011])

# %%
gamedetail_2015
# Out:
#                   team1                 team2             gameday  \
# 0             Australia                Kuwait  [09-Jan-15, 20:00]
# 1           South Korea                  Oman  [10-Jan-15, 16:00]
# 2                Kuwait           South Korea  [13-Jan-15, 18:00]
# 0                  Oman             Australia  [13-Jan-15, 20:00]
# 0             Australia           South Korea  [17-Jan-15, 19:00]
# 1                  Oman                Kuwait  [17-Jan-15, 20:00]
# 0            Uzbekistan           North Korea  [10-Jan-15, 18:00]
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 3            Uzbekistan          Saudi Arabia  [18-Jan-15, 20:00]
# 4             China, PR           North Korea  [18-Jan-15, 20:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# ...

# %%
# driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

for i in range(191220,191223):
    url_base = 'http://www.football-lineups.com/match/'
    url_sub = str(i)
    driver.get(url_base + url_sub)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
    team1List.append(team1)
    team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
    team2List.append(team2)
    time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
    timeList.append(time[0:2])
    weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
    weather1List.append(weather[0].text)
    weather2List.append(weather[1].text)
    detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[186:]
    Shots1List.append(detail[3].text)
    Shots2List.append(detail[5].text)
    Fouls1List.append(detail[6].text)
    Fouls2List.append(detail[8].text)
    possession1List.append(detail[15].text)
    possession2List.append(detail[17].text)

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)
# Out:
# ['Japan', 'Jordan', 'Palestine']
# ['Palestine', 'Iraq', 'Jordan']
# [['12-Jan-15', '18:00'], ['12-Jan-15', '19:00'], ['16-Jan-15', '18:00']]
# [' 4:58 pm AEDT  Partly Cloudy 24C', ' 5:30 pm AEST  Mostly Cloudy 25C', ' 4:58 pm AEDT  Fair 27C']
# [' 7:29 pm AEDT  Cloudy 21C', ' 8:59 pm AEST  Mostly Cloudy 24C', ' 7:00 pm AEDT  Fair 25C']
# ['-', '3', '4']
# ['Offsides ', '2', '6']
# ['-', '20', '11']
# ['Time % ', '21', '11']
# ['Height Avg ', '44', '52']
# ['1.89', '56', '48']

# %%
gamedetail_sf_2011 = pd.DataFrame(team1List)
gamedetail_sf_2011 = gamedetail_sf_2011.rename(columns = {0:'team1'})
gamedetail_sf_2011['team2'] = team2List
gamedetail_sf_2011['gameday'] = timeList
gamedetail_sf_2011['weather_d'] = weather1List
gamedetail_sf_2011['weather_t'] = weather2List
gamedetail_sf_2011['shoot1'] = Shots1List
gamedetail_sf_2011['shoot2'] = Shots2List
gamedetail_sf_2011['foul1'] = Fouls1List
gamedetail_sf_2011['foul2'] = Fouls2List
gamedetail_sf_2011['possession1'] = possession1List
gamedetail_sf_2011['possession2'] = possession2List

# %%
gamedetail_sf_2011
# Out:
#        team1      team2             gameday                         weather_d  \
# 0      Japan  Palestine  [12-Jan-15, 18:00]   4:58 pm AEDT  Partly Cloudy 24C
# 1     Jordan       Iraq  [12-Jan-15, 19:00]   5:30 pm AEST  Mostly Cloudy 25C
# 2  Palestine     Jordan  [16-Jan-15, 18:00]            4:58 pm AEDT  Fair 27C
#
#                           weather_t shoot1     shoot2 foul1    foul2  \
# 0          7:29 pm AEDT  Cloudy 21C      -  Offsides      -  Time %
# 1   8:59 pm AEST  Mostly Cloudy 24C      3          2    20       21
# 2            7:00 pm AEDT  Fair 25C      4          6    11       11
#
#    possession1 possession2
# 0  Height Avg         1.89
# 1           44          56
# 2           52          48

# %%
gamedetail_2015 = pd.concat([gamedetail_2015,gamedetail_sf_2011])

# %%
# gamedetail_2015.to_csv('./gamedetail_2015.csv',index=False,header=True)

# %%
gamedetail_2015
# Out:
#                   team1                 team2             gameday  \
# 0             Australia                Kuwait  [09-Jan-15, 20:00]
# 1           South Korea                  Oman  [10-Jan-15, 16:00]
# 2                Kuwait           South Korea  [13-Jan-15, 18:00]
# 0                  Oman             Australia  [13-Jan-15, 20:00]
# 0             Australia           South Korea  [17-Jan-15, 19:00]
# 1                  Oman                Kuwait  [17-Jan-15, 20:00]
# 0            Uzbekistan           North Korea  [10-Jan-15, 18:00]
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 3            Uzbekistan          Saudi Arabia  [18-Jan-15, 20:00]
# 4             China, PR           North Korea  [18-Jan-15, 20:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# ...

# %%
# Out:
#                   team1                 team2             gameday  \
# 0             Australia                Kuwait  [09-Jan-15, 20:00]
# 1           South Korea                  Oman  [10-Jan-15, 16:00]
# 0            Uzbekistan           North Korea  [10-Jan-15, 18:00]
# 0          Saudi Arabia             China, PR  [10-Jan-15, 19:00]
# 5  United Arab Emirates                 Qatar  [11-Jan-15, 18:00]
# 6                  Iran               Bahrain  [11-Jan-15, 20:00]
# 0                 Japan             Palestine  [12-Jan-15, 18:00]
# 1                Jordan                  Iraq  [12-Jan-15, 19:00]
# 2                Kuwait           South Korea  [13-Jan-15, 18:00]
# 0                  Oman             Australia  [13-Jan-15, 20:00]
# 1           North Korea          Saudi Arabia  [14-Jan-15, 18:00]
# 2             China, PR            Uzbekistan  [14-Jan-15, 19:00]
# 7               Bahrain  United Arab Emirates  [15-Jan-15, 18:00]
# ...

# %%
# gamedetail_2015 = pd.read_csv('./gamedetail_2015.csv')

# %%
gamedetail_2015
# Out:
#                    team1                 team2                 gameday  \
# 0              Australia                Kuwait  ['09-Jan-15', '20:00']
# 1            South Korea                  Oman  ['10-Jan-15', '16:00']
# 2                 Kuwait           South Korea  ['13-Jan-15', '18:00']
# 3                   Oman             Australia  ['13-Jan-15', '20:00']
# 4              Australia           South Korea  ['17-Jan-15', '19:00']
# 5                   Oman                Kuwait  ['17-Jan-15', '20:00']
# 6             Uzbekistan           North Korea  ['10-Jan-15', '18:00']
# 7           Saudi Arabia             China, PR  ['10-Jan-15', '19:00']
# 8            North Korea          Saudi Arabia  ['14-Jan-15', '18:00']
# 9              China, PR            Uzbekistan  ['14-Jan-15', '19:00']
# 10            Uzbekistan          Saudi Arabia  ['18-Jan-15', '20:00']
# 11             China, PR           North Korea  ['18-Jan-15', '20:00']
# ...

# %%
driver = webdriver.Chrome('./chromedriver')
team1List = []
team2List = []
timeList = []
weather1List = []
weather2List = []
Shots1List = []
Shots2List = []
Fouls1List = []
Fouls2List = []
possession1List = []
possession2List = []

for i in range(202691,202763):
    url_base = 'http://www.football-lineups.com/match/'
    url_sub = str(i)
    driver.get(url_base + url_sub)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    team1 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[0].text
    team1List.append(team1)
    team2 = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font > b' )[1].text
    team2List.append(team2)
    time = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td' )[6].text.split()
    timeList.append(time[0:2])
    weather = soup.select('#mainarea > tbody > tr > td.TDmain > table > tbody > tr > td > font' )[3:]
    weather1List.append(weather[0].text)
    weather2List.append(weather[1].text)
    detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
                   tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[186:]
    Shots1List.append(detail[3].text)
    Shots2List.append(detail[5].text)
    Fouls1List.append(detail[6].text)
    Fouls2List.append(detail[8].text)
    possession1List.append(detail[15].text)
    possession2List.append(detail[17].text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-239-a6168c130b39> in <module>
#      29     detail = soup.select('#mainarea > tbody > tr > td.TDmain > table >\
#      30                    tbody > tr > td > table > tbody > tr > td > table > tbody > tr > td' )[186:]
# ---> 31     Shots1List.append(detail[3].text)
#      32     Shots2List.append(detail[5].text)
#      33     Fouls1List.append(detail[6].text)
#
# IndexError: list index out of range

# %%
print(team1List)
print(team2List)
print(timeList)
print(weather1List)
print(weather2List)
print(Shots1List)
print(Shots2List)
print(Fouls1List)
print(Fouls2List)
print(possession1List)
print(possession2List)

# %%
gamedetail_f_2011 = pd.DataFrame(team1List)
gamedetail_f_2011 = gamedetail_f_2011.rename(columns = {0:'team1'})
gamedetail_f_2011['team2'] = team2List
gamedetail_f_2011['gameday'] = timeList
gamedetail_f_2011['weather_d'] = weather1List
gamedetail_f_2011['weather_t'] = weather2List
gamedetail_f_2011['shoot1'] = Shots1List
gamedetail_f_2011['shoot2'] = Shots2List
gamedetail_f_2011['foul1'] = Fouls1List
gamedetail_f_2011['foul2'] = Fouls2List
gamedetail_f_2011['possession1'] = possession1List
gamedetail_f_2011['possession2'] = possession2List

# %%
gamedetail_f_2011

# %%
gamedetail_2011_t = pd.concat([gamedetail_2011_t,gamedetail_f_2011])

# %%
# gamedetail_2011_t.to_csv('./gamedetail_2011.csv',index=False,header=True)
